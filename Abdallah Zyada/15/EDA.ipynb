# %%
import pandas as pd

# %%
covid_df = pd.read_csv('covid-19.csv')
covid_df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
covid_df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
covid_df['WHO Region'].value_counts()
# Out:
# Europe                   56
# Africa                   48
# Americas                 35
# Eastern Mediterranean    22
# Western Pacific          16
# South-East Asia          10
# Name: WHO Region, dtype: int64

# %%
covid_df[covid_df['Confirmed'] == covid_df['Confirmed'].max()]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
covid_df[covid_df['Deaths'] == covid_df['Deaths'].max()]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
covid_df[covid_df['Recovered'] == covid_df['Recovered'].max()]
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 23         Brazil    2442375   87618    1846641  508116      23284
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23         614          33728                3.59                  75.61
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 23                    4.74              2118646         323729
#
#     1 week % increase WHO Region
# 23              15.28   Americas

# %%
covid_df[covid_df['Active'] == covid_df['Active'].max()]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %%
covid_df.groupby('WHO Region').describe().transpose()
# Out:
# WHO Region                     Africa       Americas  Eastern Mediterranean  \
# Confirmed         count     48.000000      35.000000              22.000000
#                   mean   15066.812500  252551.028571           67761.090909
#                   std    65087.434387  817100.096342           93399.654809
#                   min       10.000000      17.000000             674.000000
#                   25%      910.000000     265.000000            3367.500000
# ...                               ...            ...                    ...
# 1 week % increase min        0.000000       0.000000              -3.840000
#                   25%        4.625000       4.410000               3.177500
#                   50%       10.555000      12.970000               5.755000
#                   75%       21.455000      19.450000              17.332500
#                   max      191.070000     119.540000              42.780000
#
# ...

# %%
pd.pivot_table(covid_df, index=['WHO Region'], columns=['Country/Region'], values='Recovered')
# Out:
# Country/Region         Afghanistan  Albania  Algeria  Andorra  Angola  \
# WHO Region
# Africa                         NaN      NaN  18837.0      NaN   242.0
# Americas                       NaN      NaN      NaN      NaN     NaN
# Eastern Mediterranean      25198.0      NaN      NaN      NaN     NaN
# Europe                         NaN   2745.0      NaN    803.0     NaN
# South-East Asia                NaN      NaN      NaN      NaN     NaN
# Western Pacific                NaN      NaN      NaN      NaN     NaN
#
# Country/Region         Antigua and Barbuda  Argentina  Armenia  Australia  \
# WHO Region
# Africa                                 NaN        NaN      NaN        NaN
# Americas                              65.0    72575.0      NaN        NaN
# Eastern Mediterranean                  NaN        NaN      NaN        NaN
# Europe                                 NaN        NaN  26665.0        NaN
# South-East Asia                        NaN        NaN      NaN        NaN
# ...

# %%
covid_df[covid_df['Confirmed last week'] == covid_df['Confirmed last week'].min()][['WHO Region', 'Country/Region']]
# Out:
#     WHO Region  Country/Region
# 183     Africa  Western Sahara

# %%
covid_df[covid_df['Active'] == covid_df['Active'].min()][['WHO Region', 'Country/Region']]
# Out:
#           WHO Region Country/Region
# 24   Western Pacific         Brunei
# 49          Americas       Dominica
# 69          Americas        Grenada
# 75            Europe       Holy See
# 143           Europe     San Marino
