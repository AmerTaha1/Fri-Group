# %%
import sqlite3
import pandas as pd
import csv

# %%
conn_1 = sqlite3.connect('books.db')
sql = 'select * from booksandcategories where Rate >= 3 and Book_name Like Mr%'
rows = conn_1.execute('select * from book_category where Rate >= ? And Book_name LIKE ? ', [3, '%Mr%']).fetchall()
conn_1.close()
rows
# Out:
# [(37, 'Mrs. Houdini', 30.25, 5, 'Historical Fiction '),
#  (232, 'My Mrs. Brown', 24.48, 3, 'Fiction '),
#  (237, 'Dear Mr. Knightley', 11.21, 5, 'Fiction ')]

# %%
conn_2 = sqlite3.connect('books.db')
sql = 'select * from book_category where Rate >= 3 and Book_name Like Mr%'
rows = conn_2.execute('select * from book_category where Rate >= ? Or Price = ? ', [3, 20]).fetchall()
conn_2.close()
rows
# Out:
# [(1, 'Sharp Objects', 47.82, 4, 'Mystery '),
#  (3, 'The Past Never Ends', 56.5, 4, 'Mystery '),
#  (5, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, 'Mystery '),
#  (9, 'A Time of Torment (Charlie Parker #14)', 48.35, 5, 'Mystery '),
#  (11, 'Poisonous (Max Revere Novels #3)', 26.8, 3, 'Mystery '),
#  (12,
#   'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   54.36,
#   4,
#   'Mystery '),
#  (13, 'Most Wanted', 35.28, 3, 'Mystery '),
#  (15, 'Boar Island (Anna Pigeon #19)', 59.48, 3, 'Mystery '),
#  (17, 'Playing with Fire', 13.71, 3, 'Mystery '),
#  (18,
#   'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   25.37,
#   5,
#   'Mystery '),
#  (19,
#   "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   52.3,
#   5,
#   'Mystery '),
#  (20,
#   'Delivering the Truth (Quaker Midwife Mystery #1)',
#   20.89,
#   4,
#   'Mystery '),
#  (21,
#   'The Mysterious Affair at Styles (Hercule Poirot #1)',
#   24.8,
# ...

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select * from book_category where Rate <> ?', [3]).fetchall()
conn_1.close()
rows
# Out:
# [(1, 'Sharp Objects', 47.82, 4, 'Mystery '),
#  (2, 'In a Dark, Dark Wood', 19.63, 1, 'Mystery '),
#  (3, 'The Past Never Ends', 56.5, 4, 'Mystery '),
#  (4, 'A Murder in Time', 16.64, 1, 'Mystery '),
#  (5, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, 'Mystery '),
#  (6, 'The Last Mile (Amos Decker #2)', 54.21, 2, 'Mystery '),
#  (7, 'That Darkness (Gardiner and Renner #1)', 13.92, 1, 'Mystery '),
#  (8, 'Tastes Like Fear (DI Marnie Rome #3)', 10.69, 1, 'Mystery '),
#  (9, 'A Time of Torment (Charlie Parker #14)', 48.35, 5, 'Mystery '),
#  (10, 'A Study in Scarlet (Sherlock Holmes #1)', 16.73, 2, 'Mystery '),
#  (12,
#   'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   54.36,
#   4,
#   'Mystery '),
#  (14, 'Hide Away (Eve Duncan #20)', 11.84, 1, 'Mystery '),
#  (16, 'The Widow', 27.26, 2, 'Mystery '),
#  (18,
#   'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   25.37,
#   5,
#   'Mystery '),
#  (19,
# ...

# %%
conn = sqlite3.connect('books.db')
rows = conn.execute('select * from book_category where Price Between ? And ? And Rate In (?, ?, ?) ', [10, 40, 3, 4, 1]).fetchall()
conn.close()
rows
# Out:
# [(2, 'In a Dark, Dark Wood', 19.63, 1, 'Mystery '),
#  (4, 'A Murder in Time', 16.64, 1, 'Mystery '),
#  (7, 'That Darkness (Gardiner and Renner #1)', 13.92, 1, 'Mystery '),
#  (8, 'Tastes Like Fear (DI Marnie Rome #3)', 10.69, 1, 'Mystery '),
#  (11, 'Poisonous (Max Revere Novels #3)', 26.8, 3, 'Mystery '),
#  (13, 'Most Wanted', 35.28, 3, 'Mystery '),
#  (14, 'Hide Away (Eve Duncan #20)', 11.84, 1, 'Mystery '),
#  (17, 'Playing with Fire', 13.71, 3, 'Mystery '),
#  (20,
#   'Delivering the Truth (Quaker Midwife Mystery #1)',
#   20.89,
#   4,
#   'Mystery '),
#  (21,
#   'The Mysterious Affair at Styles (Hercule Poirot #1)',
#   24.8,
#   4,
#   'Mystery '),
#  (25, "The Cuckoo's Calling (Cormoran Strike #1)", 19.21, 1, 'Mystery '),
#  (26, 'Extreme Prey (Lucas Davenport #26)', 25.4, 3, 'Mystery '),
#  (30, 'The Girl In The Ice (DCI Erika Foster #1)', 15.85, 3, 'Mystery '),
#  (31, 'Blood Defense (Samantha Brinkman #1)', 20.3, 3, 'Mystery '),
#  (34,
# ...

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select * from book_category Order by Price DESC Limit ?', [5]).fetchall()
conn_1.close()
rows
# Out:
# [(181, 'The Perfect Play (Play by Play #1)', 59.99, 3, 'Romance '),
#  (261, 'Last One Home (New Beginnings #1)', 59.98, 3, 'Fiction '),
#  (835, 'Civilization and Its Discontents', 59.95, 2, 'Psychology '),
#  (915, 'The Barefoot Contessa Cookbook', 59.92, 5, 'Food and Drink '),
#  (358, 'The Diary of a Young Girl', 59.9, 3, 'Nonfiction ')]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select * from book_category Order by Rate DESC, Price ASC').fetchall()[2]
conn_1.close()
rows
# Out:
# (917,
#  'The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#  11.05,
#  5,
#  'Food and Drink ')

# %%
conn_1 = sqlite3.connect('books.db')
conn_1.execute('insert into book_category(Book_name, Price, Rate, Category) values(?, ?, ?, ?)', ["added_title_1", 1.5, 1, "added"])
conn_1.commit()
conn_1.close()

# %%
conn_1 = sqlite3.connect('books.db')
conn_1.execute('update book_category set Rate = ? where Price < ?', [3, 20])
conn_1.commit()
conn_1.close()

# %%
conn_1 = sqlite3.connect('books.db')
conn_1.execute('delete from book_category where Price > ? And Rate <=?', [50, 2])
conn_1.commit()
conn_1.close()

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select COUNT(ID) from book_category where Book_name LIKE ? And Price between ? and ?', ['%Secret%', 10, 25]).fetchall()[0][0]
conn_1.commit()
conn_1.close()
rows
# Out:
# 5

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select MAX(Price) from book_category where Rate=?', [5]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(59.92,)]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select MIN(Price) from book_category where Rate=?', [5]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(20.02,)]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select AVG(Price) from book_category where Rate=?', [5]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(41.14784313725492,)]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select sum(ID) from book_category where Rate=? And Price between ? and ?', [2, 10, 40]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(40736,)]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select count(ID), Rate from book_category where Price between ? and ? group by Rate', [20, 30]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(55, 1), (40, 2), (41, 3), (34, 4), (35, 5)]

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select count(ID), Category from booksandcategories where ID > ? group by Category', [10]).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-57-495bfb7e6538> in <module>
#       1 conn_1 = sqlite3.connect('books.db')
# ----> 2 rows = conn_1.execute('select count(ID), Category from booksandcategories where ID > ? group by Category', [10]).fetchall()
#       3 conn_1.commit()
#       4 conn_1.close()
#       5 rows
#
# OperationalError: no such table: booksandcategories

# %%
conn_1 = sqlite3.connect('books.db')
rows = conn_1.execute('select * from book_category where Category like ?', ['%Music%']).fetchall()
conn_1.commit()
conn_1.close()
rows
# Out:
# [(427, 'Rip it Up and Start Again', 35.02, 5, 'Music '),
#  (428,
#   'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   57.25,
#   3,
#   'Music '),
#  (429, 'How Music Works', 37.32, 2, 'Music '),
#  (430, 'Love Is a Mix Tape (Music #1)', 18.03, 3, 'Music '),
#  (431,
#   'Please Kill Me: The Uncensored Oral History of Punk',
#   31.19,
#   4,
#   'Music '),
#  (432,
#   "Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   45.05,
#   5,
#   'Music '),
#  (434,
#   'This Is Your Brain on Music: The Science of a Human Obsession',
#   38.4,
#   1,
#   'Music '),
#  (435,
#   'Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   12.36,
#   3,
#   'Music '),
#  (436, 'No One Here Gets Out Alive', 20.02, 5, 'Music '),
#  (437, 'Life', 31.58, 5, 'Music '),
#  (439, 'Forever Rockers (The Rocker #12)', 28.8, 3, 'Music ')]

# %%
connect = sqlite3.connect('books.db')
sql = pd.read_sql('select * from book_category', connect)
df = pd.DataFrame(sql)
df.to_csv(r'bok.csv')

# %%
connect = sqlite3.connect('books.db')
rows = connect.execute('select book.Book_name,book.Price,book.Rate, category.Category from book left join category using(ID) union all select book.Book_name,book.Price,book.Rate, category.Category from category left join book using(ID) where book.ID is null').fetchall()
connect.commit()
connect.close()
rows
# Out:
# [('Sharp Objects', 47.82, 4, None),
#  ('In a Dark, Dark Wood', 19.63, 1, None),
#  ('The Past Never Ends', 56.5, 4, None),
#  ('A Murder in Time', 16.64, 1, None),
#  ('The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, None),
#  ('The Last Mile (Amos Decker #2)', 54.21, 2, None),
#  ('That Darkness (Gardiner and Renner #1)', 13.92, 1, None),
#  ('Tastes Like Fear (DI Marnie Rome #3)', 10.69, 1, None),
#  ('A Time of Torment (Charlie Parker #14)', 48.35, 5, None),
#  ('A Study in Scarlet (Sherlock Holmes #1)', 16.73, 2, None),
#  ('Poisonous (Max Revere Novels #3)', 26.8, 3, None),
#  ('Murder at the 42nd Street Library (Raymond Ambler #1)', 54.36, 4, None),
#  ('Most Wanted', 35.28, 3, None),
#  ('Hide Away (Eve Duncan #20)', 11.84, 1, None),
#  ('Boar Island (Anna Pigeon #19)', 59.48, 3, None),
#  ('The Widow', 27.26, 2, None),
#  ('Playing with Fire', 13.71, 3, None),
#  ('What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   25.37,
#   5,
#   None),
# ...
