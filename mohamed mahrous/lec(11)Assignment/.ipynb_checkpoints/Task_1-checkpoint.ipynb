# %%
import requests
import json

# %%
json_req = requests.get("https://api.exchangerate.host/latest")
data = json_req.json()
data
# Out:
# {'motd': {'msg': 'If you or your company use this project or like what we doing, please consider backing us so we can continue maintaining and evolving this project.',
#   'url': 'https://exchangerate.host/#/donate'},
#  'success': True,
#  'base': 'EUR',
#  'date': '2021-08-01',
#  'rates': {'AED': 4.356077,
#   'AFN': 94.655199,
#   'ALL': 121.486149,
#   'AMD': 576.004864,
#   'ANG': 2.128975,
#   'AOA': 757.327114,
#   'ARS': 114.686694,
#   'AUD': 1.614733,
#   'AWG': 2.135437,
#   'AZN': 2.01685,
#   'BAM': 1.951772,
#   'BBD': 2.372031,
#   'BDT': 100.674903,
#   'BGN': 1.954761,
#   'BHD': 0.447951,
#   'BIF': 2349.044682,
#   'BMD': 1.186817,
#   'BND': 1.605275,
#   'BOB': 8.188413,
#   'BRL': 6.177534,
#   'BSD': 1.186819,
#   'BTC': 0.000704,
#   'BTN': 88.122523,
#   'BWP': 13.096195,
#   'BYN': 2.975489,
#   'BZD': 2.390322,
#   'CAD': 1.480714,
#   'CDF': 2355.834055,
#   'CHF': 1.075114,
#   'CLF': 0.033459,
#   'CLP': 897.293534,
#   'CNH': 7.662594,
# ...

# %%
EUR_IN_USD = data["rates"]["USD"]
EUR_IN_USD
# Out:
# 1.186996

# %%
USD = float(input("pleas enter your amount in USD: "))
EUR = USD/EUR_IN_USD
print(f"your amount in EUR is : {EUR}")
# Out:
# pleas enter your amount in USD: 6
# your amount in EUR is : 5.054776932693961
