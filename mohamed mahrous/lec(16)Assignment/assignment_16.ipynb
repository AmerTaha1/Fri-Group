# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
x=np.linspace(1,5,11)
x
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ])

# %%
y=x**2

# %%
y
# Out:
# array([ 1.  ,  1.96,  3.24,  4.84,  6.76,  9.  , 11.56, 14.44, 17.64,
#        21.16, 25.  ])

# %%
plt.plot(x,y)

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',split=True,palette='Set2')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
df=pd.read_csv('50ulke.csv')
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
sns.distplot(df['Growth'])

# %%
sns.distplot(df['Growth'],kde=False)

# %%
sns.kdeplot(df['Growth'],shade=False)

# %%
sns.kdeplot(df['Growth'],shade=True)

# %%
sns.jointplot(x='Growth',y='Per person',data=df)

# %%
sns.jointplot(x='Growth',y='Per person',data=df,kind='hex')

# %%
sns.jointplot(x='Growth',y='Per person',data=df,kind='kde')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Countries')
# Out:
# C:\Users\nancy\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\nancy\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\nancy\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\nancy\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\nancy\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.pairplot(df,vars=['Growth','Per person'])

# %%
sns.boxplot(x='Continent',y='Growth',data=df)

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
sns.boxplot(x='Continent',y='Growth',data=df)

# %%
sns.violinplot(x='Continent',y='Growth',data=df)

# %%
sns.violinplot(x='Continent',y='Growth',data=df,palette='Set1')

# %%
sns.stripplot(x='Continent',y='Growth',data=df)

# %%
sns.swarmplot(x='Continent',y='Growth',data=df)

# %%
sns.barplot(x='Continent',y='Growth',data=df)

# %%
sns.barplot(x='Continent',y='Growth',data=df,estimator=np.max)

# %%
sns.countplot(x='Continent',data=df)

# %%
sns.boxplot(x='Continent',y='Growth',data=df)
sns.stripplot(x='Continent',y='Growth',data=df)

# %%
sns.catplot(x='Continent',y='Growth',data=df,kind='swarm')

# %%
flo=df.pivot_table(index='Countries',columns='Continent',values='Growth')
flo
# Out:
# Continent                 Africa  Asia  Europe  North America  Oceania  \
# Countries
# Argentina                    NaN   NaN     NaN            NaN      NaN
# Australia                    NaN   NaN     NaN            NaN     2.27
# Austria                      NaN   NaN    2.90            NaN      NaN
# Bangladesh                   NaN  7.14     NaN            NaN      NaN
# Belgium                      NaN   NaN    1.71            NaN      NaN
# Brazil                       NaN   NaN     NaN            NaN      NaN
# Canada                       NaN   NaN     NaN           3.00      NaN
# Chile                        NaN   NaN     NaN            NaN      NaN
# China                        NaN  6.86     NaN            NaN      NaN
# Colombia                     NaN   NaN     NaN            NaN      NaN
# Czech Republic               NaN   NaN    4.29            NaN      NaN
# Denmark                      NaN   NaN    2.11            NaN      NaN
# ...

# %%
cmap=sns.cubehelix_palette(dark=0,light=1,reverse=True,as_cmap=True)
sns.heatmap(flo,cmap=cmap)

# %%
sns.heatmap(flo)
