# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('covid-19.csv')
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.shape
# Out:
# (187, 15)

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df[['Confirmed','Deaths']]
# Out:
#      Confirmed  Deaths
# 0        36263    1269
# 1         4880     144
# 2        27973    1163
# 3          907      52
# 4          950      41
# ..         ...     ...
# 182      10621      78
# 183         10       1
# 184       1691     483
# 185       4552     140
# 186       2704      36
#
# [187 rows x 2 columns]

# %%
df[df['Confirmed']<.3]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, Confirmed last week, 1 week change, 1 week % increase, WHO Region]
# Index: []

# %%
df['new']=df['WHO Region'].apply(lambda x:x.upper())
df['new']
# Out:
# 0      EASTERN MEDITERRANEAN
# 1                     EUROPE
# 2                     AFRICA
# 3                     EUROPE
# 4                     AFRICA
#                ...
# 182    EASTERN MEDITERRANEAN
# 183                   AFRICA
# 184    EASTERN MEDITERRANEAN
# 185                   AFRICA
# 186                   AFRICA
# Name: new, Length: 187, dtype: object

# %%
df['new'].value_counts()
# Out:
# EUROPE                   56
# AFRICA                   48
# AMERICAS                 35
# EASTERN MEDITERRANEAN    22
# WESTERN PACIFIC          16
# SOUTH-EAST ASIA          10
# Name: new, dtype: int64

# %%
df['new'].nunique()
# Out:
# 6

# %%
df['Deaths'].mean()
# Out:
# 3497.51871657754

# %%
df[df['Deaths']>0.66]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df['Recovered'].quantile(.2)
# Out:
# 252.00000000000014

# %%
df['Active'].std()
# Out:
# 213326.1733714289

# %%
df[df['Country/Region']=='Yemen']['Recovered'].std()
# Out:
# nan

# %%
df[df['Country/Region']=='Yemen']['Recovered'].mean()
# Out:
# 833.0

# %%
df.groupby('Recovered').mean()
# Out:
#            Confirmed         Deaths        Active     New cases   New deaths  \
# Recovered
# 0            37065.5    2539.666667  3.452583e+04    257.833333     4.166667
# 8               10.0       1.000000  1.000000e+00      0.000000     0.000000
# 11              62.0       0.000000  5.100000e+01      0.000000     0.000000
# 12              12.0       0.000000  0.000000e+00      0.000000     0.000000
# 13              14.0       0.000000  1.000000e+00      1.000000     0.000000
# ...              ...            ...           ...           ...          ...
# 319954      347923.0    9187.000000  1.878200e+04   2133.000000    75.000000
# 602249      816680.0   13334.000000  2.010970e+05   5607.000000    85.000000
# 951166     1480073.0   33408.000000  4.954990e+05  44457.000000   637.000000
# 1325804    4290259.0  148011.000000  2.816444e+06  56336.000000  1076.000000
# 1846641    2442375.0   87618.000000  5.081160e+05  23284.000000   614.000000
#
# ...

# %%
df.groupby('Country/Region').describe().transpose()
# Out:
# C:\anaconda\lib\site-packages\numpy\lib\function_base.py:3961: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# Country/Region           Afghanistan  Albania   Algeria  Andorra  Angola  \
# Confirmed         count         1.00      1.0      1.00      1.0    1.00
#                   mean      36263.00   4880.0  27973.00    907.0  950.00
#                   std            NaN      NaN       NaN      NaN     NaN
#                   min       36263.00   4880.0  27973.00    907.0  950.00
#                   25%       36263.00   4880.0  27973.00    907.0  950.00
# ...                              ...      ...       ...      ...     ...
# 1 week % increase min           2.07     17.0     18.07      2.6   26.84
#                   25%           2.07     17.0     18.07      2.6   26.84
#                   50%           2.07     17.0     18.07      2.6   26.84
#                   75%           2.07     17.0     18.07      2.6   26.84
# ...

# %%
sum((df['New recovered']=='749') & (df['Country/Region']=='Albania'))
# Out:
# 0

# %%
df.to_csv('new.csv')
