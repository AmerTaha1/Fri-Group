# %% [markdown]
# # Titanic
#
# ## Abdelrahman Muhammad

# %%
import pandas as pd
df=pd.read_csv('Titanic.csv') #sep='\t' note the format is tsv not csv 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().any().any()
# Out:
# True

# %%
df=df.drop(['Cabin', 'Name'], axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df2 = df.apply(le.fit_transform)
df2.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch  Ticket  Fare  \
# 0            0         0       2    1   28      1      0     523    18
# 1            1         1       0    0   51      1      0     596   207
# 2            2         1       2    0   34      0      0     669    41
# 3            3         1       0    0   47      1      0      49   189
# 4            4         0       2    1   47      0      0     472    43
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %%
df['Ticket'].describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %%
df2=df2.drop(['Ticket'], axis=1)   # useless

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    445.000000    0.383838    1.308642    0.647587   48.609428
# std     257.353842    0.486592    0.836071    0.477990   25.539308
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     222.500000    0.000000    1.000000    0.000000   28.000000
# 50%     445.000000    0.000000    2.000000    1.000000   42.000000
# 75%     667.500000    1.000000    2.000000    1.000000   69.000000
# max     890.000000    1.000000    2.000000    1.000000   88.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.507295    0.381594  105.355780    1.538721
# std      1.005995    0.806057   70.082521    0.794231
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   40.500000    1.000000
# ...

# %%
df2.isnull().any().any()
# Out:
# False

# %%
df2['PassengerId'].describe()
# Out:
# count    891.000000
# mean     445.000000
# std      257.353842
# min        0.000000
# 25%      222.500000
# 50%      445.000000
# 75%      667.500000
# max      890.000000
# Name: PassengerId, dtype: float64

# %%
df2=df2.drop(['PassengerId'], axis=1)   # useless

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (18, 18)
sns.heatmap(df2.corr())
plt.title('Correlation heatmap for the Data', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation heatmap for the Data')

# %%
df2
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       2    1   28      1      0    18         2
# 1           1       0    0   51      1      0   207         0
# 2           1       2    0   34      0      0    41         2
# 3           1       0    0   47      1      0   189         2
# 4           0       2    1   47      0      0    43         2
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 886         0       1    1   35      0      0    85         2
# 887         1       0    0   24      0      0   153         2
# 888         0       2    0   88      1      2   131         2
# 889         1       0    1   34      0      0   153         0
# 890         0       2    1   42      0      0    30         1
#
# [891 rows x 8 columns]

# %%
x = df2.iloc[:,1:]
y = df2["Survived"]

# getting the shapes of new data sets x and y
print("shape of x:", x.shape)
print("shape of y:", y.shape)
# Out:
# shape of x: (891, 7)
# shape of y: (891,)

# %%
x
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0         2    1   28      1      0    18         2
# 1         0    0   51      1      0   207         0
# 2         2    0   34      0      0    41         2
# 3         0    0   47      1      0   189         2
# 4         2    1   47      0      0    43         2
# ..      ...  ...  ...    ...    ...   ...       ...
# 886       1    1   35      0      0    85         2
# 887       0    0   24      0      0   153         2
# 888       2    0   88      1      2   131         2
# 889       0    1   34      0      0   153         0
# 890       2    1   42      0      0    30         1
#
# [891 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# gettiing the shapes
print("shape of x_train: ", x_train.shape)
print("shape of x_test: ", x_test.shape)
print("shape of y_train: ", y_train.shape)
print("shape of y_test: ", y_test.shape)
# Out:
# shape of x_train:  (623, 7)
# shape of x_test:  (268, 7)
# shape of y_train:  (623,)
# shape of y_test:  (268,)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(x_train, y_train)

predict =clf.predict(x_test)

accuracy_score(y_test, predict)
# Out:
# 0.7686567164179104
