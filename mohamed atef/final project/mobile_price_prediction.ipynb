# %% [markdown]
# # mobile prediction

# %%
pip install pyforest

# %% [markdown]
# ### id:ID
# ### battery_power:Total energy a battery can store in one time measured in mAh
# ### blue:Has bluetooth or not
# ### clock_speed:speed at which microprocessor executes instructions
# ### dual_sim:Has dual sim support or not
# ### fc:Front Camera mega pixels
# ### four_g:Has 4G or not
# ### int_memory:Internal Memory in Gigabytes
# ### m_dep:Mobile Depth in cm
# ### mobile_wt:Weight of mobile phone
# ### n_cores:Number of cores of processor
# ### pc:Primary Camera mega pixels
# ### px_height:Pixel Resolution Height
# ### px_width:Pixel Resolution Width
# ### ram:Random Access Memory in Megabytes
# ### sc_h:Screen Height of mobile in cm
# ### sc_w:Screen Width of mobile in cm
# ### talk_time:longest time that a single battery charge will last when you are
# ### three_g:Has 3G or not
# ### touch_screen:Has touch screen or not
# ### wifi:Has wifi or not

# %% [markdown]
# ## importing the libraries and reading the data

# %%
import pyforest

# %%
df=pd.read_csv('mobile prediction.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ## Detect the outliers

# %%
columns=df.columns
for col in columns:
    plt.figure()
    sns.boxplot(y=df[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/pyforest/__init__.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   from .utils import (

# %%
df.drop(df[df['fc']>15].index,axis=0,inplace=True)
sns.boxplot(y=df['fc'])

# %%
df.describe()
# Out:
#        battery_power         blue  ...         wifi  price_range
# count    1958.000000  1958.000000  ...  1958.000000  1958.000000
# mean     1237.478039     0.495914  ...     0.502043     1.501021
# std       439.358223     0.500111  ...     0.500124     1.119689
# min       501.000000     0.000000  ...     0.000000     0.000000
# 25%       851.250000     0.000000  ...     0.000000     0.000000
# 50%      1225.000000     0.000000  ...     1.000000     2.000000
# 75%      1614.000000     1.000000  ...     1.000000     3.000000
# max      1998.000000     1.000000  ...     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
df['price_range'].value_counts()
# Out:
# 3    491
# 0    491
# 2    490
# 1    486
# Name: price_range, dtype: int64

# %% [markdown]
# ## Data visualization

# %%
plt.figure(figsize=(20, 6))
ax = sns.histplot(df['price_range'].sort_values(), bins=56)
sns.rugplot(data=df['price_range'], height=.05)
plt.xticks(np.linspace(df['price_range'].min(), df['price_range'].max(), 56, dtype=int, endpoint = True))
plt.show()

# %%
plt.figure(figsize=(13,7))
plt.subplot(1,2,1)
sns.barplot(x='price_range', y='px_height',data=df,palette='Reds')
plt.subplot(1,2,2)
sns.barplot(x='price_range', y='px_width',data=df,palette='Greens')            
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'price_range',x='blue',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'price_range',x='wifi',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'price_range',y='battery_power',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'price_range',y='ram',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['three_g'],hue=df['price_range'],palette='Blues')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['four_g'],hue=df['price_range'],palette='Oranges')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x = 'price_range',y='int_memory',data=df,hue='dual_sim')
plt.show()

# %%
correlation = df.corr()
plt.figure(figsize=(20,20))
plt.title('Correlation Matrix')
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

# %% [markdown]
# # observation
#
# from the analysis and visualization we can say that all the featurs are important to be selected in modeling
#
# and the features tha informs if the mobile have this option or not like(blue -fc-dual_sim-four_g-three_g-touch_screen-wifi)
# has a great effect on the price
#
# and seems the best algorithms for the data are XGBClassifier and svm
#
# so,i will start cross-validation for both and see what gives the best params and score

# %% [markdown]
# ## preparing the data

# %%
x=df.drop('price_range',axis=1)
y=df['price_range']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[-0.90035658, -0.99186151,  0.83496726, ..., -1.77931376,
#         -1.0061476 ,  0.99592251],
#        [-0.49284008,  1.00820527, -1.24953886, ...,  0.56201443,
#          0.99388996, -1.00409418],
#        [-1.53553594,  1.00820527, -1.24953886, ...,  0.56201443,
#          0.99388996, -1.00409418],
#        ...,
#        [ 1.53335931, -0.99186151, -0.75906683, ...,  0.56201443,
#          0.99388996, -1.00409418],
#        [ 0.62498453, -0.99186151, -0.75906683, ...,  0.56201443,
#          0.99388996,  0.99592251],
#        [-1.65619725,  1.00820527,  0.58973124, ...,  0.56201443,
#          0.99388996,  0.99592251]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %% [markdown]
# ## choosing the best model algorithm

# %%
from xgboost import XGBClassifier
from sklearn import svm
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'XGBClassifier': {
            'model':XGBClassifier(),
            'params' : {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
            },
}

}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=10, return_train_score=False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#            model  best_score                                        best_params
# 0            svm    0.971276                      {'C': 20, 'kernel': 'linear'}
# 1  XGBClassifier    0.914458  {'colsample_bytree': 1.0, 'gamma': 0.5, 'max_d...

# %%
model=svm.SVC(C=20,kernel='linear').fit(x_train,y_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.9566326530612245

# %%
from sklearn.metrics import classification_report
pred = model.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        96
#            1       0.96      0.94      0.95       102
#            2       0.93      0.93      0.93       100
#            3       0.96      0.97      0.96        94
#
#     accuracy                           0.96       392
#    macro avg       0.96      0.96      0.96       392
# weighted avg       0.96      0.96      0.96       392

# %%
import joblib
model=joblib.dump(model,'model.h5')
scaler=joblib.dump(scaler,'scaler.5h')
